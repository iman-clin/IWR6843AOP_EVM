# %% [markdown]
# # CNN training for pattern recognition on Range-Doppler Heatmap (3D) and Static Range-Azimuth Heatmap (2D)

# %%
#import tensorflow.keras
import os
from os import listdir
from os.path import isdir, join
import numpy as np
from keras import layers, models, metrics
from subprocess import check_output
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Conv3D,MaxPooling3D,Dense,Flatten,Dropout
from keras.optimizers import Adam,SGD
from keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# ## Gathering the databases

# %%
# Doppler CNN files paths
feature_sets_path  = os.getcwd() + '\\Features\\'
filename_dop = 'all_targets_doppler_1211_6587'
features_filename_dop = filename_dop + '.npz'
dop_model_filename = filename_dop + '.h5'

# %%
# Azimuth CNN files paths
filename_az = 'all_targets_azimuth_0_37230'
features_filename_az = filename_az + '.npz'
az_model_filename = filename_az + '.h5'

# %%
# Load feature sets
features_set_dop = np.load(join(feature_sets_path, features_filename_dop))
print('features for doppler set:',features_set_dop.files)

features_set_az = np.load(join(feature_sets_path, features_filename_az))
print('features for azimuth set:',features_set_az.files)
# Out:
# features for doppler set: ['x_train', 'y_train', 'x_val', 'y_val', 'x_test', 'y_test']
# features for azimuth set: ['x_train', 'y_train', 'x_val', 'y_val', 'x_test', 'y_test']

# %%
# Assign Doppler feature sets
x_train_dop = features_set_dop['x_train']
y_train_dop = features_set_dop['y_train']
x_val_dop = features_set_dop['x_val']
y_val_dop = features_set_dop['y_val']
x_test_dop = features_set_dop['x_test']
y_test_dop = features_set_dop['y_test']

# %%
# Assign Azimuth feature sets
x_train_az = features_set_az['x_train']
y_train_az = features_set_az['y_train']
x_val_az = features_set_az['x_val']
y_val_az = features_set_az['y_val']
x_test_az = features_set_az['x_test']
y_test_az = features_set_az['y_test']

# %%
# Look at tensor dimensions
print('Doppler:')
print('training input shape :',x_train_dop.shape)
print('validation input shape :',x_val_dop.shape)
print('test input shape :',x_test_dop.shape)

print('Azimuth:')
print('training input shape :',x_train_az.shape)
print('validation input shape :',x_val_az.shape)
print('test input shape :',x_test_az.shape)
# Out:
# Doppler:
# training input shape : (15438, 256, 4)
# validation input shape : (3286, 256, 4)
# test input shape : (3286, 256, 4)
# Azimuth:
# training input shape : (129024, 31)
# validation input shape : (27648, 31)
# test input shape : (27648, 31)

# %%
# Sample shape
NUMBER_ROWS_DOP = 31
NUMBER_COlUMNS_DOP = 256
NUMBER_ROWS_AZ = NUMBER_COlUMNS_DOP
NUMBER_COlUMNS_AZ = NUMBER_ROWS_DOP
DEPTH = 4

# %%
# CNN for TF expects (batch (lote), height, width, channels)
# So we reshape the input tensors with a "color" channel of ''

# Doppler
x_train_dop = x_train_dop.reshape(int(x_train_dop.shape[0]/(NUMBER_ROWS_DOP)),
                          NUMBER_ROWS_DOP,
                          NUMBER_COlUMNS_DOP,
                          DEPTH,
                          1)
x_val_dop = x_val_dop.reshape(int(x_val_dop.shape[0]/(NUMBER_ROWS_DOP)),
                      NUMBER_ROWS_DOP,
                      NUMBER_COlUMNS_DOP,
                      DEPTH,
                      1)
x_test_dop = x_test_dop.reshape(int(x_test_dop.shape[0]/(NUMBER_ROWS_DOP)),
                        NUMBER_ROWS_DOP,
                        NUMBER_COlUMNS_DOP,
                        DEPTH,
                        1)

print('number of training samples :',x_train_dop.shape[0])
print('number of validation samples :',x_val_dop.shape[0])
print('number of test samples :',x_test_dop.shape[0])

sample_shape_dop = x_test_dop.shape[1:]
print('sample shape :',sample_shape_dop)
# Out:
# number of training samples : 498
# number of validation samples : 106
# number of test samples : 106
# sample shape : (31, 256, 4, 1)

# %%
# Azimuth
x_train_az = x_train_az.reshape(int(x_train_az.shape[0]/(NUMBER_ROWS_AZ)),
                          NUMBER_ROWS_AZ,
                          NUMBER_COlUMNS_AZ,
                          1)
x_val_az = x_val_az.reshape(int(x_val_az.shape[0]/(NUMBER_ROWS_AZ)),
                          NUMBER_ROWS_AZ,
                          NUMBER_COlUMNS_AZ,
                          1)
x_test_az = x_test_az.reshape(int(x_test_az.shape[0]/(NUMBER_ROWS_AZ)),
                          NUMBER_ROWS_AZ,
                          NUMBER_COlUMNS_AZ,
                          1)

print('number of training samples :',x_train_az.shape[0])
print('number of validation samples :',x_val_az.shape[0])
print('number of test samples :',x_test_az.shape[0])

sample_shape_az = x_test_az.shape[1:]
print('sample shape :',sample_shape_az)
# Out:
# number of training samples : 504
# number of validation samples : 108
# number of test samples : 108
# sample shape : (256, 31, 1)

# %% [markdown]
# ## 3D Model construction and training (Range-Doppler Heatmap pattern recognition)

# %% [markdown]
# ### Model Construction

# %%
# Build model
# Based on: https://www.geeksforgeeks.org/python-image-classification-using-keras/
model_dop = models.Sequential()

# Convolution filters
model_dop.add(layers.Conv3D(filters=2, kernel_size=(2,2,2), kernel_initializer='random_normal', activation='relu', padding = 'same', input_shape=sample_shape_dop, name = 'Conv3D_layer1'))
model_dop.add(layers.MaxPooling3D(pool_size=(2,2,1), name = 'Pooling_layer1'))
model_dop.add(Dropout(0.5))

model_dop.add(Conv3D(filters=4, kernel_size=(2,2,2), kernel_initializer='random_normal', activation='relu', padding = 'same', name = 'Conv3D_layer2'))
model_dop.add(MaxPooling3D(pool_size=(2,2,1), name = 'Pooling_layer2'))
model_dop.add(Dropout(0.5))

model_dop.add(Conv3D(filters=8, kernel_size=(2,2,2), kernel_initializer='random_normal', activation='relu', padding = 'same', name = 'Conv3D_layer3'))
model_dop.add(MaxPooling3D(pool_size=(2,2,1), name = 'Pooling_layer3'))
model_dop.add(Dropout(0.5))

# Classifier
model_dop.add(Flatten())
model_dop.add(Dense(128, kernel_initializer='random_normal', activation='relu'))
model_dop.add(Dropout(0.5))
model_dop.add(Dense(32, kernel_initializer='random_normal', activation='relu'))
model_dop.add(Dropout(0.5))


# Check Number of Classes Before Training
model_dop.add(Dense(2, activation='sigmoid'))

# Display model
model_dop.layers
model_dop.summary()
# Out:
# c:\Users\Iman\Desktop\Stage\code\myenv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Conv3D_layer1 (Conv3D)          │ (None, 31, 256, 4, 2)  │            18 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pooling_layer1 (MaxPooling3D)   │ (None, 15, 128, 4, 2)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 15, 128, 4, 2)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv3D_layer2 (Conv3D)          │ (None, 15, 128, 4, 4)  │            68 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pooling_layer2 (MaxPooling3D)   │ (None, 7, 64, 4, 4)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 7, 64, 4, 4)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv3D_layer3 (Conv3D)          │ (None, 7, 64, 4, 8)    │           264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pooling_layer3 (MaxPooling3D)   │ (None, 3, 32, 4, 8)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 3, 32, 4, 8)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       393,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 397,888 (1.52 MB)
#  Trainable params: 397,888 (1.52 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Model training

# %%
# PatientEearly Stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20, restore_best_weights=True)

# Add training parameters to model
model_dop.compile(loss='sparse_categorical_crossentropy',
             optimizer=keras.optimizers.Adam(learning_rate=0.0001), #SGD, RMSProp, Adam, nadam
             loss_weights=0.01,
             metrics=['accuracy'])

# Train
history_dop = model_dop.fit(x_train_dop,
                   y_train_dop,
                   epochs=250,
                   batch_size=4,
                   validation_data=(x_val_dop,y_val_dop),
                   callbacks = [es])
# Out:
# Epoch 1/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.5121 - loss: 0.0069 - val_accuracy: 0.3774 - val_loss: 0.0069
# Epoch 2/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.5448 - loss: 0.0069 - val_accuracy: 0.3774 - val_loss: 0.0070
# Epoch 3/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.5246 - loss: 0.0069 - val_accuracy: 0.3774 - val_loss: 0.0070
# Epoch 4/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5401 - loss: 0.0069 - val_accuracy: 0.3774 - val_loss: 0.0070
# Epoch 5/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.5002 - loss: 0.0069 - val_accuracy: 0.3774 - val_loss: 0.0070
# Epoch 6/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.4993 - loss: 0.0069 - val_accuracy: 0.3774 - val_loss: 0.0070
# Epoch 7/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5184 - loss: 0.0069 - val_accuracy: 0.3774 - val_loss: 0.0070
# Epoch 8/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.5357 - loss: 0.0068 - val_accuracy: 0.3774 - val_loss: 0.0070
# Epoch 9/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.5087 - loss: 0.0068 - val_accuracy: 0.3774 - val_loss: 0.0070
# Epoch 10/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.5313 - loss: 0.0067 - val_accuracy: 0.5755 - val_loss: 0.0068
# Epoch 11/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.6114 - loss: 0.0065 - val_accuracy: 0.5000 - val_loss: 0.0068
# Epoch 12/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7148 - loss: 0.0064 - val_accuracy: 0.7264 - val_loss: 0.0063
# Epoch 13/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7796 - loss: 0.0057 - val_accuracy: 0.9434 - val_loss: 0.0055
# Epoch 14/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8072 - loss: 0.0054 - val_accuracy: 0.8962 - val_loss: 0.0048
# Epoch 15/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8337 - loss: 0.0046 - val_accuracy: 0.9340 - val_loss: 0.0042
# Epoch 16/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8568 - loss: 0.0042 - val_accuracy: 0.6226 - val_loss: 0.0044
# Epoch 17/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8600 - loss: 0.0037 - val_accuracy: 0.8491 - val_loss: 0.0035
# Epoch 18/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8938 - loss: 0.0032 - val_accuracy: 0.9811 - val_loss: 0.0033
# Epoch 19/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8876 - loss: 0.0032 - val_accuracy: 0.9434 - val_loss: 0.0027
# Epoch 20/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8783 - loss: 0.0033 - val_accuracy: 0.9340 - val_loss: 0.0031
# Epoch 21/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9086 - loss: 0.0031 - val_accuracy: 0.9906 - val_loss: 0.0028
# Epoch 22/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9055 - loss: 0.0027 - val_accuracy: 0.9623 - val_loss: 0.0028
# Epoch 23/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9010 - loss: 0.0027 - val_accuracy: 0.9717 - val_loss: 0.0023
# Epoch 24/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9084 - loss: 0.0026 - val_accuracy: 0.9340 - val_loss: 0.0027
# Epoch 25/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9070 - loss: 0.0026 - val_accuracy: 0.9434 - val_loss: 0.0018
# Epoch 26/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9137 - loss: 0.0022 - val_accuracy: 0.9811 - val_loss: 0.0021
# Epoch 27/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9250 - loss: 0.0020 - val_accuracy: 0.9906 - val_loss: 0.0021
# Epoch 28/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9330 - loss: 0.0021 - val_accuracy: 0.8774 - val_loss: 0.0027
# Epoch 29/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8913 - loss: 0.0028 - val_accuracy: 0.9811 - val_loss: 0.0018
# Epoch 30/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9384 - loss: 0.0019 - val_accuracy: 0.9623 - val_loss: 0.0015
# Epoch 31/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9461 - loss: 0.0021 - val_accuracy: 0.8774 - val_loss: 0.0025
# Epoch 32/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9043 - loss: 0.0026 - val_accuracy: 0.9906 - val_loss: 0.0019
# Epoch 33/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9305 - loss: 0.0022 - val_accuracy: 0.9434 - val_loss: 0.0015
# Epoch 34/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9484 - loss: 0.0017 - val_accuracy: 0.6226 - val_loss: 0.0051
# Epoch 35/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9180 - loss: 0.0023 - val_accuracy: 0.9906 - val_loss: 0.0015
# Epoch 36/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9417 - loss: 0.0020 - val_accuracy: 0.9623 - val_loss: 0.0011
# Epoch 37/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9420 - loss: 0.0019 - val_accuracy: 0.9623 - val_loss: 0.0011
# Epoch 38/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9388 - loss: 0.0016 - val_accuracy: 0.9811 - val_loss: 0.0012
# Epoch 39/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9518 - loss: 0.0017 - val_accuracy: 0.9906 - val_loss: 0.0015
# Epoch 40/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9322 - loss: 0.0019 - val_accuracy: 0.9811 - val_loss: 0.0010
# Epoch 41/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9446 - loss: 0.0018 - val_accuracy: 0.9811 - val_loss: 0.0011
# Epoch 42/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9289 - loss: 0.0020 - val_accuracy: 0.8962 - val_loss: 0.0022
# Epoch 43/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9391 - loss: 0.0016 - val_accuracy: 0.8774 - val_loss: 0.0023
# Epoch 44/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9595 - loss: 0.0015 - val_accuracy: 0.9811 - val_loss: 9.9165e-04
# Epoch 45/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9434 - loss: 0.0020 - val_accuracy: 0.9906 - val_loss: 0.0011
# Epoch 46/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9606 - loss: 0.0012 - val_accuracy: 0.9906 - val_loss: 9.1030e-04
# Epoch 47/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9249 - loss: 0.0021 - val_accuracy: 0.9906 - val_loss: 0.0011
# Epoch 48/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9618 - loss: 0.0013 - val_accuracy: 0.8679 - val_loss: 0.0023
# Epoch 49/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9328 - loss: 0.0016 - val_accuracy: 0.9906 - val_loss: 8.4162e-04
# Epoch 50/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9553 - loss: 0.0013 - val_accuracy: 0.9528 - val_loss: 0.0014
# Epoch 51/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9497 - loss: 0.0015 - val_accuracy: 0.9623 - val_loss: 0.0016
# Epoch 52/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9615 - loss: 0.0013 - val_accuracy: 0.9623 - val_loss: 7.8990e-04
# Epoch 53/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9585 - loss: 0.0014 - val_accuracy: 0.7736 - val_loss: 0.0038
# Epoch 54/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9520 - loss: 0.0014 - val_accuracy: 0.9623 - val_loss: 8.8888e-04
# Epoch 55/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9311 - loss: 0.0020 - val_accuracy: 0.9906 - val_loss: 8.9718e-04
# Epoch 56/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9724 - loss: 0.0013 - val_accuracy: 0.9906 - val_loss: 9.4829e-04
# Epoch 57/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9560 - loss: 0.0014 - val_accuracy: 0.9906 - val_loss: 7.4118e-04
# Epoch 58/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9361 - loss: 0.0021 - val_accuracy: 0.9906 - val_loss: 8.8975e-04
# Epoch 59/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9504 - loss: 0.0017 - val_accuracy: 0.9906 - val_loss: 9.1931e-04
# Epoch 60/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9482 - loss: 0.0015 - val_accuracy: 0.9717 - val_loss: 0.0012
# Epoch 61/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9439 - loss: 0.0018 - val_accuracy: 0.9906 - val_loss: 6.9229e-04
# Epoch 62/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9654 - loss: 0.0011 - val_accuracy: 0.9906 - val_loss: 7.4646e-04
# Epoch 63/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9419 - loss: 0.0013 - val_accuracy: 0.9717 - val_loss: 6.6409e-04
# Epoch 64/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9611 - loss: 0.0012 - val_accuracy: 0.9906 - val_loss: 7.0537e-04
# Epoch 65/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9639 - loss: 0.0012 - val_accuracy: 0.9717 - val_loss: 6.3720e-04
# Epoch 66/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9661 - loss: 0.0015 - val_accuracy: 0.9528 - val_loss: 0.0015
# Epoch 67/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9283 - loss: 0.0016 - val_accuracy: 0.9906 - val_loss: 6.5292e-04
# Epoch 68/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9749 - loss: 9.5310e-04 - val_accuracy: 0.9906 - val_loss: 9.4762e-04
# Epoch 69/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9700 - loss: 0.0010 - val_accuracy: 0.9717 - val_loss: 6.7141e-04
# Epoch 70/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9603 - loss: 0.0012 - val_accuracy: 0.9623 - val_loss: 7.2170e-04
# Epoch 71/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9663 - loss: 0.0014 - val_accuracy: 0.9528 - val_loss: 0.0011
# Epoch 72/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9432 - loss: 0.0016 - val_accuracy: 0.9811 - val_loss: 6.7639e-04
# Epoch 73/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9658 - loss: 8.9205e-04 - val_accuracy: 0.9906 - val_loss: 8.9251e-04
# Epoch 74/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9694 - loss: 7.6840e-04 - val_accuracy: 0.9717 - val_loss: 6.0569e-04
# Epoch 75/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9604 - loss: 0.0011 - val_accuracy: 0.9528 - val_loss: 9.0673e-04
# Epoch 76/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9785 - loss: 9.2429e-04 - val_accuracy: 0.9906 - val_loss: 6.6267e-04
# Epoch 77/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9452 - loss: 0.0015 - val_accuracy: 0.9811 - val_loss: 5.8019e-04
# Epoch 78/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9589 - loss: 0.0014 - val_accuracy: 0.9434 - val_loss: 0.0016
# Epoch 79/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9405 - loss: 0.0014 - val_accuracy: 0.9528 - val_loss: 0.0011
# Epoch 80/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9748 - loss: 9.2076e-04 - val_accuracy: 0.9906 - val_loss: 5.2218e-04
# Epoch 81/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9742 - loss: 9.4432e-04 - val_accuracy: 0.9717 - val_loss: 5.9056e-04
# Epoch 82/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9496 - loss: 0.0012 - val_accuracy: 0.9717 - val_loss: 0.0013
# Epoch 83/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9613 - loss: 0.0013 - val_accuracy: 0.9906 - val_loss: 5.5605e-04
# Epoch 84/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9736 - loss: 8.9799e-04 - val_accuracy: 0.9906 - val_loss: 5.4864e-04
# Epoch 85/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9697 - loss: 0.0010 - val_accuracy: 0.9717 - val_loss: 6.0448e-04
# Epoch 86/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9585 - loss: 0.0014 - val_accuracy: 0.9528 - val_loss: 0.0012
# Epoch 87/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9511 - loss: 0.0012 - val_accuracy: 0.9623 - val_loss: 6.4634e-04
# Epoch 88/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9466 - loss: 0.0014 - val_accuracy: 0.9623 - val_loss: 8.1442e-04
# Epoch 89/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9510 - loss: 0.0013 - val_accuracy: 0.9717 - val_loss: 6.0800e-04
# Epoch 90/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9640 - loss: 0.0014 - val_accuracy: 0.9717 - val_loss: 5.7530e-04
# Epoch 91/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9535 - loss: 0.0015 - val_accuracy: 0.9528 - val_loss: 0.0012
# Epoch 92/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9713 - loss: 6.7476e-04 - val_accuracy: 0.9906 - val_loss: 7.2212e-04
# Epoch 93/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9785 - loss: 7.4604e-04 - val_accuracy: 0.9717 - val_loss: 5.2668e-04
# Epoch 94/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9506 - loss: 0.0014 - val_accuracy: 0.9906 - val_loss: 5.2061e-04
# Epoch 95/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9781 - loss: 7.2805e-04 - val_accuracy: 0.9623 - val_loss: 6.7187e-04
# Epoch 96/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9701 - loss: 9.4985e-04 - val_accuracy: 0.9717 - val_loss: 6.0576e-04
# Epoch 97/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9599 - loss: 0.0012 - val_accuracy: 0.9906 - val_loss: 4.9490e-04
# Epoch 98/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9747 - loss: 8.3789e-04 - val_accuracy: 0.9906 - val_loss: 4.9455e-04
# Epoch 99/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9677 - loss: 8.5916e-04 - val_accuracy: 1.0000 - val_loss: 4.6318e-04
# Epoch 100/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9504 - loss: 0.0011 - val_accuracy: 0.9623 - val_loss: 0.0013
# Epoch 101/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9702 - loss: 0.0011 - val_accuracy: 0.9906 - val_loss: 4.2568e-04
# Epoch 102/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9689 - loss: 9.1020e-04 - val_accuracy: 0.9623 - val_loss: 6.0660e-04
# Epoch 103/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9631 - loss: 0.0011 - val_accuracy: 0.9906 - val_loss: 5.0078e-04
# Epoch 104/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9449 - loss: 0.0014 - val_accuracy: 0.9717 - val_loss: 5.8270e-04
# Epoch 105/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9677 - loss: 0.0011 - val_accuracy: 0.9906 - val_loss: 4.7945e-04
# Epoch 106/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9745 - loss: 8.5927e-04 - val_accuracy: 0.9623 - val_loss: 6.4654e-04
# Epoch 107/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9398 - loss: 0.0014 - val_accuracy: 0.9906 - val_loss: 5.5950e-04
# Epoch 108/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9624 - loss: 9.9492e-04 - val_accuracy: 0.9623 - val_loss: 6.9921e-04
# Epoch 109/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9805 - loss: 7.1605e-04 - val_accuracy: 1.0000 - val_loss: 4.5756e-04
# Epoch 110/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9755 - loss: 7.6037e-04 - val_accuracy: 0.9811 - val_loss: 8.2549e-04
# Epoch 111/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9734 - loss: 9.3961e-04 - val_accuracy: 0.9623 - val_loss: 6.1182e-04
# Epoch 112/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9823 - loss: 7.3448e-04 - val_accuracy: 0.9906 - val_loss: 3.9210e-04
# Epoch 113/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9762 - loss: 8.0841e-04 - val_accuracy: 0.9717 - val_loss: 5.6605e-04
# Epoch 114/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9620 - loss: 8.3574e-04 - val_accuracy: 0.9906 - val_loss: 4.9293e-04
# Epoch 115/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9613 - loss: 0.0013 - val_accuracy: 0.9717 - val_loss: 5.5555e-04
# Epoch 116/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9575 - loss: 0.0013 - val_accuracy: 0.9906 - val_loss: 5.3110e-04
# Epoch 117/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9744 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 4.7842e-04
# Epoch 118/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9680 - loss: 7.3981e-04 - val_accuracy: 0.9717 - val_loss: 8.8200e-04
# Epoch 119/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9519 - loss: 0.0012 - val_accuracy: 0.9811 - val_loss: 5.5375e-04
# Epoch 120/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9686 - loss: 7.6959e-04 - val_accuracy: 0.9906 - val_loss: 3.9164e-04
# Epoch 121/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9639 - loss: 0.0015 - val_accuracy: 0.9717 - val_loss: 0.0013
# Epoch 122/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9573 - loss: 0.0013 - val_accuracy: 0.9717 - val_loss: 5.9867e-04
# Epoch 123/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9690 - loss: 6.5400e-04 - val_accuracy: 0.9528 - val_loss: 9.0546e-04
# Epoch 124/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9616 - loss: 9.3956e-04 - val_accuracy: 0.9906 - val_loss: 6.2663e-04
# Epoch 125/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9590 - loss: 0.0013 - val_accuracy: 0.9717 - val_loss: 0.0010
# Epoch 126/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9452 - loss: 0.0013 - val_accuracy: 0.9528 - val_loss: 8.9531e-04
# Epoch 127/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9804 - loss: 9.5514e-04 - val_accuracy: 0.9906 - val_loss: 4.7536e-04
# Epoch 128/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9703 - loss: 8.6738e-04 - val_accuracy: 0.9717 - val_loss: 5.1360e-04
# Epoch 129/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9442 - loss: 0.0015 - val_accuracy: 0.9906 - val_loss: 3.8901e-04
# Epoch 130/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9663 - loss: 8.7204e-04 - val_accuracy: 0.9623 - val_loss: 6.2567e-04
# Epoch 131/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9670 - loss: 9.8135e-04 - val_accuracy: 0.9906 - val_loss: 4.0189e-04
# Epoch 132/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9840 - loss: 7.1325e-04 - val_accuracy: 0.9623 - val_loss: 6.9645e-04
# Epoch 133/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9802 - loss: 5.6020e-04 - val_accuracy: 0.9906 - val_loss: 3.3420e-04
# Epoch 134/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9772 - loss: 8.0550e-04 - val_accuracy: 0.9906 - val_loss: 3.0867e-04
# Epoch 135/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9652 - loss: 0.0012 - val_accuracy: 0.9623 - val_loss: 7.1315e-04
# Epoch 136/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9814 - loss: 5.8880e-04 - val_accuracy: 1.0000 - val_loss: 3.6983e-04
# Epoch 137/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9698 - loss: 0.0010 - val_accuracy: 0.9717 - val_loss: 5.3904e-04
# Epoch 138/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9690 - loss: 8.3574e-04 - val_accuracy: 0.9717 - val_loss: 5.5650e-04
# Epoch 139/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9534 - loss: 0.0010 - val_accuracy: 0.9906 - val_loss: 3.5960e-04
# Epoch 140/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9773 - loss: 5.9308e-04 - val_accuracy: 0.9906 - val_loss: 3.1105e-04
# Epoch 141/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9700 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 3.6052e-04
# Epoch 142/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9929 - loss: 4.4485e-04 - val_accuracy: 0.9623 - val_loss: 6.0290e-04
# Epoch 143/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9697 - loss: 8.3658e-04 - val_accuracy: 0.9811 - val_loss: 4.8330e-04
# Epoch 144/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9744 - loss: 7.8113e-04 - val_accuracy: 0.9906 - val_loss: 3.4515e-04
# Epoch 145/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9762 - loss: 7.6885e-04 - val_accuracy: 0.9906 - val_loss: 4.4713e-04
# Epoch 146/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9688 - loss: 0.0010 - val_accuracy: 0.9906 - val_loss: 3.7632e-04
# Epoch 147/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9609 - loss: 0.0010 - val_accuracy: 0.9528 - val_loss: 8.3803e-04
# Epoch 148/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9695 - loss: 0.0011 - val_accuracy: 0.9528 - val_loss: 0.0011
# Epoch 149/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9576 - loss: 9.5509e-04 - val_accuracy: 1.0000 - val_loss: 5.2137e-04
# Epoch 150/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9762 - loss: 8.3289e-04 - val_accuracy: 0.9623 - val_loss: 7.0571e-04
# Epoch 151/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9740 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 4.2613e-04
# Epoch 152/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9740 - loss: 8.4351e-04 - val_accuracy: 0.9906 - val_loss: 3.7734e-04
# Epoch 153/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9849 - loss: 5.4621e-04 - val_accuracy: 0.9528 - val_loss: 0.0011
# Epoch 154/250
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9815 - loss: 5.2669e-04 - val_accuracy: 0.9906 - val_loss: 3.3727e-04
# Epoch 154: early stopping
# Restoring model weights from the end of the best epoch: 134.

# %% [markdown]
# ### Plotting results

# %%
# Plot results
import matplotlib.pyplot as plt

acc = history_dop.history['accuracy']
val_acc = history_dop.history['val_accuracy']
loss = history_dop.history['loss']
val_loss = history_dop.history['val_loss']
#recall = history.history['recall_1']
#val_recall = history.history['val_recall_1']
#precision = history.history['precision']
#val_precision = history.history['val_precision']


epochs = range(1, len(acc) + 1)

# Plot the training and validation accuracy
plt.plot(epochs, acc, 'g', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

# Plot the training and validation loss
plt.plot(epochs, loss, 'g', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
# Model evaluation on test set
test_loss, test_acc = model_dop.evaluate(x_test_dop, y_test_dop, verbose=2)
# Out:
# 4/4 - 0s - 28ms/step - accuracy: 0.9906 - loss: 4.5667e-04

# %%
models.save_model(model_dop, feature_sets_path + '\\' + dop_model_filename)

print('saved model path :',feature_sets_path + '/' + dop_model_filename)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# saved model path : c:\Users\Iman\Desktop\Stage\code\2sensors\Features\/all_targets_doppler_1211_6587.h5

# %% [markdown]
# ## 2D Model construction and training

# %% [markdown]
# ### Model construction

# %%
# Build model
# Based on: https://www.geeksforgeeks.org/python-image-classification-using-keras/
model_az = models.Sequential()

# Convolution filters
model_az.add(layers.Conv2D(filters=4, kernel_size=(3,3), kernel_initializer='random_normal', activation='relu', padding = 'same', input_shape=sample_shape_az, name = 'Conv2D_layer1'))
model_az.add(layers.MaxPooling2D(pool_size=(2,2), name = 'Pooling_layer1'))

model_az.add(layers.Conv2D(filters=16, kernel_size=(3,3), kernel_initializer='random_normal', activation='relu', padding = 'same', name = 'Conv2D_layer2'))
model_az.add(layers.MaxPooling2D(pool_size=(2,2), name = 'Pooling_layer2'))

model_az.add(layers.Conv2D(filters=32, kernel_size=(3,3), kernel_initializer='random_normal', activation='relu', padding = 'same', name = 'Conv2D_layer3'))
model_az.add(layers.MaxPooling2D(pool_size=(2,2), name = 'Pooling_layer3'))

# Classifier
model_az.add(Flatten())
model_az.add(Dense(128, kernel_initializer='random_normal', activation='relu'))
model_az.add(Dropout(0.5))
model_az.add(Dense(32, kernel_initializer='random_normal', activation='relu'))
model_az.add(Dropout(0.5))

# Check Number of Classes Before Training
model_az.add(Dense(2, activation='sigmoid'))

# Display model
model_az.layers
model_az.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Conv2D_layer1 (Conv2D)          │ (None, 256, 31, 4)     │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pooling_layer1 (MaxPooling2D)   │ (None, 128, 15, 4)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D_layer2 (Conv2D)          │ (None, 128, 15, 16)    │           592 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pooling_layer2 (MaxPooling2D)   │ (None, 64, 7, 16)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D_layer3 (Conv2D)          │ (None, 64, 7, 32)      │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pooling_layer3 (MaxPooling2D)   │ (None, 32, 3, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │       393,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 402,810 (1.54 MB)
#  Trainable params: 402,810 (1.54 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Model training

# %%
# PatientEearly Stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20, restore_best_weights=True)

# Add training parameters to model
model_az.compile(loss='sparse_categorical_crossentropy',
             optimizer=keras.optimizers.Adam(learning_rate=0.0005), #SGD, RMSProp, Adam, nadam
             loss_weights=0.001,
             metrics=['accuracy'])

# Train
history_az = model_az.fit(x_train_az,
                   y_train_az,
                   epochs=500,
                   batch_size=2,
                   validation_data=(x_val_az,y_val_az),
                   callbacks = [es])
# Out:
# Epoch 1/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.5402 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 6.8971e-05
# Epoch 2/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9151 - loss: 1.9034e-04 - val_accuracy: 1.0000 - val_loss: 3.7320e-06
# Epoch 3/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9787 - loss: 5.8589e-05 - val_accuracy: 1.0000 - val_loss: 4.0491e-07
# Epoch 4/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9756 - loss: 5.6129e-05 - val_accuracy: 1.0000 - val_loss: 2.6223e-08
# Epoch 5/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9955 - loss: 1.7664e-05 - val_accuracy: 1.0000 - val_loss: 3.9670e-09
# Epoch 6/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 1.0000 - loss: 1.3031e-05 - val_accuracy: 1.0000 - val_loss: 1.0707e-10
# Epoch 7/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9972 - loss: 8.5804e-06 - val_accuracy: 1.0000 - val_loss: 9.9341e-12
# Epoch 8/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 1.0000 - loss: 1.7800e-06 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 9/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9998 - loss: 1.7773e-06 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 10/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9876 - loss: 4.7715e-05 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 11/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9943 - loss: 8.2472e-06 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 12/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 1.0000 - loss: 1.3427e-06 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 13/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 6.0263e-06 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 14/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9991 - loss: 2.1600e-06 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 15/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.0598e-06 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 16/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 2.6623e-06 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 17/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9850 - loss: 6.1450e-05 - val_accuracy: 1.0000 - val_loss: 8.6096e-10
# Epoch 18/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9908 - loss: 1.2261e-05 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 19/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 7.8767e-07 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 20/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 1.0000 - loss: 8.5551e-07 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 21/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9957 - loss: 5.5736e-06 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 22/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.7331e-07 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 23/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 7.1611e-08 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 24/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 1.1517e-06 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 25/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 5.1492e-08 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 26/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 4.3355e-06 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 27/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 1.3356e-07 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 28/500
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 1.8252e-08 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 8.

# %%
# Plot results
import matplotlib.pyplot as plt

acc = history_az.history['accuracy']
val_acc = history_az.history['val_accuracy']
loss = history_az.history['loss']
val_loss = history_az.history['val_loss']
#recall = history.history['recall_1']
#val_recall = history.history['val_recall_1']
#precision = history.history['precision']
#val_precision = history.history['val_precision']


epochs = range(1, len(acc) + 1)

# Plot the training and validation accuracy
plt.plot(epochs, acc, 'g', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

# Plot the training and validation loss
plt.plot(epochs, loss, 'g', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
# Model evaluation on test set
test_loss, test_acc = model_az.evaluate(x_test_az, y_test_az, verbose=2)
# Out:
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 0.0000e+00

# %%
models.save_model(model_az, feature_sets_path + '\\' + az_model_filename)

print('saved model path :',feature_sets_path + '/' + az_model_filename)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# saved model path : c:\Users\Iman\Desktop\Stage\code\2sensors\Features\/all_targets_azimuth_0_37230.h5

# %% [markdown]
# ## Confusion matrix

# %%
import seaborn as sns
import tensorflow as tf

# %%
y_true=y_train_dop
predict_y=model_dop.predict(x_train_dop)
y_pred=np.argmax(predict_y,axis=1)

classes = [0,1]
con_mat = tf.math.confusion_matrix(labels=y_true, predictions=y_pred).numpy()
con_mat_norm = np.around(con_mat.astype('float')) #/ con_mat.sum(axis=1)[:, np.newaxis], decimals=2)
con_mat_df = pd.DataFrame(con_mat_norm,
                     index = classes,
                     columns = classes)

figure = plt.figure(figsize=(8, 8))
sns.heatmap(con_mat_df, annot=True,cmap=plt.cm.Blues)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.xticks([0,1,2],['banging', 'penetration','steady'])
plt.yticks([0,1,2],['banging', 'penetration','steady'])
plt.show()
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step

# %%
0.
y_true=y_train_az
predict_y=model_az.predict(x_train_az)
y_pred=np.argmax(predict_y,axis=1)

classes = [0,1]
con_mat = tf.math.confusion_matrix(labels=y_true, predictions=y_pred).numpy()
con_mat_norm = np.around(con_mat.astype('float')) #/ con_mat.sum(axis=1)[:, np.newaxis], decimals=2)
con_mat_df = pd.DataFrame(con_mat_norm,
                     index = classes,
                     columns = classes)

figure = plt.figure(figsize=(8, 8))
sns.heatmap(con_mat_df, annot=True,cmap=plt.cm.Blues)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.xticks([0,1,2],['banging', 'penetration','steady'])
plt.yticks([0,1,2],['banging', 'penetration','steady'])
plt.show()
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
# Prediction test with unclassified parameters
import scipy.interpolate as spi

# Load archive with the data to be predicted, put in shape with preparing_dataset_1folder
test_npz = np.load(os.getcwd()+'\\all_targets_0_13017_test_classes_55.npz')
test_in = test_npz['x_test']                                  

print(test_in.shape)
test_in_reshape = test_in.reshape(int(test_in.shape[0]/(NUMBER_ROWS_AZ)),                  # Resize with sample shape
                          NUMBER_ROWS_AZ,
                          NUMBER_COlUMNS_AZ,
                          1)

print('number of samples :',test_in_reshape.shape[0])
print('test samples shape :',test_in_reshape.shape[1:])

# Prediction on test sample pack
label = model_az.predict(test_in_reshape)
num_samples = test_in_reshape.shape[0]

# Loop throught the sample pack to display some of the predictions
for i in range (0,num_samples,10):
    print("Predicted Class for sample",i,"(0-idle, 1-presence) \n0 : ",label[i][0],"\n1 : ",label[i][1])    # Print predicted class
    sample = test_in[128*i:128*(i+1),:].reshape(
                          NUMBER_ROWS_AZ,
                          NUMBER_COlUMNS_AZ)
    range_res = 0.0436
    range_bins = sample.shape[0]
    angle_bins = sample.shape[1]
    theta = np.arcsin(np.linspace(-angle_bins / 2 + 1, angle_bins / 2 - 1, angle_bins) * (2 / angle_bins))  # Angular linear space for plotting
    range = np.linspace(0, range_bins - 1, range_bins) * range_res                                          # Range linear space for plotting
    range = np.maximum(range,0)                                                                                 # Keep only positive range value (later add range bias correction)
    range_depth = range_bins * range_res                                                         
    range_width, grid_res = range_depth/2, 64

    # Grid construction
    posX = np.outer(range, np.sin(theta))
    posY = np.outer(range, np.cos(theta))
    xlin = np.linspace(-np.floor(range_width), np.ceil(range_width), angle_bins)
    ylin = np.linspace(0, range_depth, range_bins)
    xgrid, ygrid = np.meshgrid(xlin, ylin)
    ra_grid = spi.griddata((posX.flatten(), posY.flatten()), sample.flatten(),(xgrid, ygrid), method='cubic')
    grid_init = 1
        
    hmplot = plt.contourf(xlin,ylin,sample,cmap='Spectral_r')
    plt.title(i)
    plt.show()
    #print("Expected prediction : ",expected[i],"\n")


"""     fig, subs = plt.subplots(2,2)
    for x in range(0,4,1): 
        f = sample[:,:,x]
        # read the csv file
        if (x < 2):
            subs[x][0].imshow(f, cmap='Spectral_r', interpolation='nearest', aspect='auto')
        else:
            subs[x-2][1].imshow(f, cmap='Spectral_r', interpolation='nearest', aspect='auto') """ #Doppler plotting
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 5
#       2 import scipy.interpolate as spi
#       4 # Load archive with the data to be predicted, put in shape with preparing_dataset_1folder
# ----> 5 test_npz = np.load(os.getcwd()+'\\all_targets_0_13017_test_classes_55.npz')
#       6 test_in = test_npz['x_test']
#       8 print(test_in.shape)
#
# File c:\Users\Iman\Desktop\Stage\code\myenv\Lib\site-packages\numpy\lib\npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\Users\\Iman\\Desktop\\Stage\\code\\2sensors\\all_targets_0_13017_test_classes_55.npz'
